# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('SaharaTemp.csv', sep=',', na_values='.')
gender_data = data.groupby('Date')

figure1 = plt.bar(data['Date'], data['Sahara_Temp'])
plt.xlabel('Year')
plt.ylabel('Temperature(°C)')
plt.title('Average Monthly Temperatures in the Sahara Desert')
plt.savefig('BrainScatter.jpg', dpi = 1200)
plt.show()
